# %% [markdown]
# # Assignment 2 - Recurrent Neural Networks

# %% [markdown]
# ## Programming (Full points: 100)

# %% [markdown]
# In this assignment, our goal is to use PyTorch to implement Recurrent Neural Networks (RNN) for sentiment analysis task. Sentiment analysis is to classify sentences (input) into certain sentiments (output labels), which includes positive, negative and neutral.
#
# We will use a benckmark dataset, SST, for this assignment.
# * we download the SST dataset from torchtext package, and do some preprocessing to build vocabulary and split the dataset into training/validation/test sets. You don't need to modify the code in this step.

# %%
import copy

import torch
from torch import nn
from torch import optim
import torchtext
from torchtext import data
from torchtext import datasets


# Check if a GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

TEXT = data.Field(sequential=True, batch_first=True, lower=True)
LABEL = data.LabelField()

# Load data splits
train_data, val_data, test_data = datasets.SST.splits(TEXT, LABEL)

# Build dictionary
TEXT.build_vocab(train_data)
LABEL.build_vocab(train_data)

# Hyperparameters
vocab_size = len(TEXT.vocab)
label_size = len(LABEL.vocab)
padding_idx = TEXT.vocab.stoi['<pad>']
embedding_dim = 128
hidden_dim = 256

# Build iterators, and move them to the GPU
train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train_data, val_data, test_data), 
    batch_size=32,
    device=device)

# %% [markdown]
# * define the training and evaluation function in the cell below.
# ### (25 points)

# %%
def train(model, iterator, optimizer, criterion, clip_grad=1.0):
    model.train()
    total_loss = 0.0
    total_correct = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    for batch in iterator:
        optimizer.zero_grad()
        text = batch.text.to(device)  # Move text data to the GPU
        label = batch.label.to(device)  # Move label data to the GPU
        
        predictions = model(text)
        loss = criterion(predictions, label)
        loss.backward()
        
        # Gradient clipping to prevent exploding gradients
#         torch.nn.utils.clip_grad_norm_(model.parameters(), clip_grad)
        
        optimizer.step()
        
        total_loss += loss.item()
        total_correct += (predictions.argmax(1) == label).sum().item()
    
    return total_loss / len(iterator), total_correct / len(iterator.dataset)

# Define a function for evaluation
def evaluate(model, iterator, criterion):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        for batch in iterator:
            text = batch.text.to(device)  # Move text data to the GPU
            label = batch.label.to(device)  # Move label data to the GPU
            
            predictions = model(text)
            loss = criterion(predictions, label)
            
            total_loss += loss.item()
            total_correct += (predictions.argmax(1) == label).sum().item()
    
    return total_loss / len(iterator), total_correct / len(iterator.dataset)

# %% [markdown]
# * build a RNN model for sentiment analysis in the cell below.
# We have provided several hyperparameters we needed for building the model, including vocabulary size (vocab_size), the word embedding dimension (embedding_dim), the hidden layer dimension (hidden_dim), the number of layers (num_layers) and the number of sentence labels (label_size). Please fill in the missing codes, and implement a RNN model.
# ### (40 points)

# %%
class RNNClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, label_size, padding_idx, num_layers=1, momentum=0.9):
        super(RNNClassifier, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.label_size = label_size
        self.num_layers = num_layers

        # Define the layers required for sentiment analysis.
        self.embedding = nn.Embedding(self.vocab_size, self.embedding_dim, padding_idx=padding_idx)
        self.rnn = nn.RNN(self.embedding_dim, self.hidden_dim, num_layers=self.num_layers, batch_first=True)
        self.fc = nn.Linear(self.hidden_dim, self.label_size)
        self.dropout = nn.Dropout(0.5)

        # Set the momentum for the optimizer
        self.momentum = momentum

    def zero_state(self, batch_size):
        # Implement the function, which returns an initial hidden state.
        return torch.zeros(self.num_layers, batch_size, self.hidden_dim)

    def forward(self, text):
        # Implement the forward function of the model.
        h0 = self.zero_state(text.size(0)).to(text.device)
        embedding = self.embedding(text)
        rnn_output, _ = self.rnn(embedding, h0)
        output = self.fc(rnn_output[:, -1, :])
        return output

# %% [markdown]
# * train the model and compute the accuracy in the cell below.
# ### (20 points)

# %%
from torch.optim import lr_scheduler

# Define a learning rate scheduler


num_epochs = 10
learning_rate = 0.001

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = RNNClassifier(vocab_size, embedding_dim, hidden_dim, label_size, padding_idx,3,None)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)


for epoch in range(num_epochs):
    train_loss, train_acc = train(model, train_iter, optimizer, criterion)
    val_loss, val_acc = evaluate(model, val_iter, criterion)
    
    scheduler.step()
    
    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')


# model.load_state_dict(torch.load('best_model.pt'))
test_loss, test_acc = evaluate(model, test_iter, criterion)
print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch 1/10, Train Loss: 1.1942, Train Acc: 0.3848, Val Loss: 1.1052, Val Acc: 0.3969
# Epoch 2/10, Train Loss: 1.1512, Train Acc: 0.3878, Val Loss: 1.2136, Val Acc: 0.3688
# Epoch 3/10, Train Loss: 1.1722, Train Acc: 0.3817, Val Loss: 1.0687, Val Acc: 0.3960
# Epoch 4/10, Train Loss: 1.1172, Train Acc: 0.3965, Val Loss: 1.1583, Val Acc: 0.3951
# Epoch 5/10, Train Loss: 1.1490, Train Acc: 0.3857, Val Loss: 1.1252, Val Acc: 0.4069
# Epoch 6/10, Train Loss: 1.1081, Train Acc: 0.3908, Val Loss: 1.0992, Val Acc: 0.3951
# Epoch 7/10, Train Loss: 1.1201, Train Acc: 0.3991, Val Loss: 1.1310, Val Acc: 0.3951
# Epoch 8/10, Train Loss: 1.1071, Train Acc: 0.3917, Val Loss: 1.1056, Val Acc: 0.4069
# Epoch 9/10, Train Loss: 1.1001, Train Acc: 0.3976, Val Loss: 1.0986, Val Acc: 0.3951
# Epoch 10/10, Train Loss: 1.0941, Train Acc: 0.4085, Val Loss: 1.1041, Val Acc: 0.3678
# Test Loss: 1.0928, Test Acc: 0.3538

# %% [markdown]
# * try to train a model with better accuracy in the cell below. For example, you can use different optimizers such as SGD and Adam. You can also compare different hyperparameters and model size.
# ### (15 points), to obtain FULL point in this problem, the accuracy needs to be higher than 70%

# %%
embedding_dim2 = 300
hidden_dim2 = 512  
num_epochs2 = 20
layers = 2
momentum = None

learning_rate_adam = 0.001
learning_rate_sgd = 0.0001
model = RNNClassifier(vocab_size, embedding_dim2, hidden_dim2, label_size, padding_idx,layers,momentum)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer_adam = optim.Adam(model.parameters(), lr=learning_rate_adam)
optimizer_sgd = optim.SGD(model.parameters(), lr=learning_rate_sgd)

scheduler_adam = lr_scheduler.StepLR(optimizer_adam, step_size=1, gamma=0.95)
scheduler_sdg = lr_scheduler.StepLR(optimizer_sgd, step_size=1, gamma=0.95)

for epoch in range(num_epochs2):
    train_loss, train_acc = train(model, train_iter, optimizer_adam, criterion)
    val_loss, val_acc = evaluate(model, val_iter, criterion)
    
    scheduler_adam.step()
    
    print(f'Adam - Epoch {epoch+1}/{num_epochs2}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

test_loss, test_acc = evaluate(model, test_iter, criterion)
print(f'Test Loss (Adam): {test_loss:.4f}, Test Acc (Adam): {test_acc:.4f}')
# Out:
# Adam - Epoch 1/20, Train Loss: 1.0959, Train Acc: 0.3866, Val Loss: 1.0727, Val Acc: 0.3606
# Adam - Epoch 2/20, Train Loss: 1.0723, Train Acc: 0.4168, Val Loss: 1.0984, Val Acc: 0.4051
# Adam - Epoch 3/20, Train Loss: 1.0688, Train Acc: 0.4080, Val Loss: 1.0834, Val Acc: 0.3778
# Adam - Epoch 4/20, Train Loss: 1.0693, Train Acc: 0.4018, Val Loss: 1.0665, Val Acc: 0.4069
# Adam - Epoch 5/20, Train Loss: 1.0639, Train Acc: 0.4115, Val Loss: 1.0791, Val Acc: 0.3751
# Adam - Epoch 6/20, Train Loss: 1.0683, Train Acc: 0.4038, Val Loss: 1.0862, Val Acc: 0.3969
# Adam - Epoch 7/20, Train Loss: 1.0665, Train Acc: 0.4088, Val Loss: 1.0983, Val Acc: 0.3978
# Adam - Epoch 8/20, Train Loss: 1.0700, Train Acc: 0.3984, Val Loss: 1.0697, Val Acc: 0.4223
# Adam - Epoch 9/20, Train Loss: 1.0596, Train Acc: 0.4149, Val Loss: 1.0721, Val Acc: 0.3896
# Adam - Epoch 10/20, Train Loss: 1.0639, Train Acc: 0.4142, Val Loss: 1.0779, Val Acc: 0.3896
# Adam - Epoch 11/20, Train Loss: 1.0664, Train Acc: 0.4060, Val Loss: 1.0757, Val Acc: 0.3778
# Adam - Epoch 12/20, Train Loss: 1.0688, Train Acc: 0.4155, Val Loss: 1.0791, Val Acc: 0.4060
# Adam - Epoch 13/20, Train Loss: 1.0628, Train Acc: 0.4109, Val Loss: 1.0747, Val Acc: 0.3515
# Adam - Epoch 14/20, Train Loss: 1.0599, Train Acc: 0.4139, Val Loss: 1.0762, Val Acc: 0.4187
# Adam - Epoch 15/20, Train Loss: 1.0740, Train Acc: 0.3969, Val Loss: 1.0665, Val Acc: 0.3896
# Adam - Epoch 16/20, Train Loss: 1.0694, Train Acc: 0.4044, Val Loss: 1.0762, Val Acc: 0.3933
# Adam - Epoch 17/20, Train Loss: 1.0630, Train Acc: 0.4064, Val Loss: 1.0873, Val Acc: 0.4205
# Adam - Epoch 18/20, Train Loss: 1.0580, Train Acc: 0.4149, Val Loss: 1.0709, Val Acc: 0.3933
# Adam - Epoch 19/20, Train Loss: 1.0573, Train Acc: 0.4103, Val Loss: 1.0766, Val Acc: 0.4124
# Adam - Epoch 20/20, Train Loss: 1.0553, Train Acc: 0.4154, Val Loss: 1.0750, Val Acc: 0.4223
# Test Loss (Adam): 1.0640, Test Acc (Adam): 0.4050

# %%
for epoch in range(num_epochs2):
    train_loss, train_acc = train(model, train_iter, optimizer_sgd, criterion)
    val_loss, val_acc = evaluate(model, val_iter, criterion)
    
    scheduler_sdg.step()
    
    print(f'SGD - Epoch {epoch+1}/{num_epochs2}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')
    
test_loss_sgd, test_acc_sgd = evaluate(model, test_iter, criterion)
print(f'Test Loss (SGD): {test_loss_sgd:.4f}, Test Acc (SGD): {test_acc_sgd:.4f}')
# Out:
# SGD - Epoch 1/20, Train Loss: 1.0530, Train Acc: 0.4106, Val Loss: 1.0590, Val Acc: 0.4114
# SGD - Epoch 2/20, Train Loss: 1.0471, Train Acc: 0.4143, Val Loss: 1.0597, Val Acc: 0.4114
# SGD - Epoch 3/20, Train Loss: 1.0473, Train Acc: 0.4205, Val Loss: 1.0596, Val Acc: 0.4033
# SGD - Epoch 4/20, Train Loss: 1.0474, Train Acc: 0.4205, Val Loss: 1.0598, Val Acc: 0.4033
# SGD - Epoch 5/20, Train Loss: 1.0472, Train Acc: 0.4199, Val Loss: 1.0598, Val Acc: 0.4033
# SGD - Epoch 6/20, Train Loss: 1.0471, Train Acc: 0.4225, Val Loss: 1.0598, Val Acc: 0.4033
# SGD - Epoch 7/20, Train Loss: 1.0471, Train Acc: 0.4225, Val Loss: 1.0601, Val Acc: 0.4033
# SGD - Epoch 8/20, Train Loss: 1.0473, Train Acc: 0.4225, Val Loss: 1.0603, Val Acc: 0.4033
# SGD - Epoch 9/20, Train Loss: 1.0473, Train Acc: 0.4225, Val Loss: 1.0600, Val Acc: 0.4033
# SGD - Epoch 10/20, Train Loss: 1.0472, Train Acc: 0.4225, Val Loss: 1.0604, Val Acc: 0.4033
# SGD - Epoch 11/20, Train Loss: 1.0473, Train Acc: 0.4225, Val Loss: 1.0602, Val Acc: 0.4033
# SGD - Epoch 12/20, Train Loss: 1.0467, Train Acc: 0.4225, Val Loss: 1.0604, Val Acc: 0.4033
# SGD - Epoch 13/20, Train Loss: 1.0472, Train Acc: 0.4225, Val Loss: 1.0599, Val Acc: 0.4033
# SGD - Epoch 14/20, Train Loss: 1.0471, Train Acc: 0.4225, Val Loss: 1.0603, Val Acc: 0.4033
# SGD - Epoch 15/20, Train Loss: 1.0472, Train Acc: 0.4225, Val Loss: 1.0598, Val Acc: 0.4033
# SGD - Epoch 16/20, Train Loss: 1.0470, Train Acc: 0.4225, Val Loss: 1.0598, Val Acc: 0.4042
# SGD - Epoch 17/20, Train Loss: 1.0469, Train Acc: 0.4219, Val Loss: 1.0605, Val Acc: 0.4033
# SGD - Epoch 18/20, Train Loss: 1.0473, Train Acc: 0.4225, Val Loss: 1.0599, Val Acc: 0.4033
# SGD - Epoch 19/20, Train Loss: 1.0470, Train Acc: 0.4221, Val Loss: 1.0602, Val Acc: 0.4033
# SGD - Epoch 20/20, Train Loss: 1.0468, Train Acc: 0.4225, Val Loss: 1.0599, Val Acc: 0.4033
# Test Loss (SGD): 1.0340, Test Acc (SGD): 0.4113

# %%
# Define hyperparameter ranges
import itertools


embedding_dim_range = [128, 256, 512, 1024]
hidden_dim_range = [128,256, 512, 1024]
num_layers_range = [1, 2, 3,4]
learning_rate_range = [0.0001, 0.001, 0.01]
momentum_range = [0.8, 0.85, 0.9, None]
optimizer_list = ['SGD', 'Adam', 'RMSprop']

# Create a list of hyperparameter combinations
hyperparameters_grid = list(itertools.product(
    embedding_dim_range, hidden_dim_range, num_layers_range,
    learning_rate_range, momentum_range, optimizer_list))

# Convert the list of combinations into a list of dictionaries
hyperparameters_grid = [
    {
        'embedding_dim2': emb_dim,
        'hidden_dim2': hid_dim,
        'num_layers': num_layers,
        'optimizer': optimizer,
        'learning_rate': lr,
        'momentum': momentum
    }
    for emb_dim, hid_dim, num_layers, lr, momentum, optimizer in hyperparameters_grid
]
print(hyperparameters_grid)
print(len(hyperparameters_grid))
# Out:
# [{'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.0001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.0001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.0001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.0001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.001, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.001, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.001, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.001, 'momentum': None}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.01, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.01, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.01, 'momentum': 0.8}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.01, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.01, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'RMSprop', 'learning_rate': 0.01, 'momentum': 0.85}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.01, 'momentum': 0.9}, {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.01, 'momentum': ...
# 2304

# %%
import os


def save_checkpoint(model, optimizer, iteration, checkpoint_path):
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'iteration': iteration,
    }
    torch.save(checkpoint, checkpoint_path)
    
# Define a function to load the latest checkpoint if available
def load_latest_checkpoint(model, optimizer, checkpoint_dir):
    checkpoint_files = [f for f in os.listdir(checkpoint_dir) if f.endswith('.pt')]
    if not checkpoint_files:
        return model, optimizer, 0
    
    # Sort checkpoint files by name (which includes epoch and iteration)
    checkpoint_files.sort()
    latest_checkpoint = checkpoint_files[-1]
    
    checkpoint_path = os.path.join(checkpoint_dir, latest_checkpoint)
    checkpoint = torch.load(checkpoint_path)
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    iteration = checkpoint['iteration']
    
    return model, optimizer, iteration

# Your existing code continues here

# Define the directory where checkpoints are saved
checkpoint_dir = 'checkpoints/'

model, optimizer, start_iteration = load_latest_checkpoint(model, optimizer, checkpoint_dir)

# %%
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader


best_hyperparameters = None
best_val_accuracy = 0.0
best_epochs_to_accuracy = None  # Track the epoch range for best validation accuracy
desired_accuracy = 0.7  # Set the desired accuracy threshold
num_epochs2 = 100  # Change the number of epochs as needed
iteration = 0


# Loop through hyperparameters
for hyperparameters in hyperparameters_grid:
    # Extract hyperparameters
    embedding_dim2 = hyperparameters['embedding_dim2']
    hidden_dim2 = hyperparameters['hidden_dim2']
    num_layers = hyperparameters['num_layers']
    optimizer_type = hyperparameters['optimizer']
    learning_rate = hyperparameters['learning_rate']

    # Create your model and optimizer based on hyperparameters
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    model = RNNClassifier(vocab_size, embedding_dim2, hidden_dim2, label_size, padding_idx, num_layers=num_layers).to(device)
    criterion = nn.CrossEntropyLoss()
    
    if optimizer_type == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    elif optimizer_type == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    elif optimizer_type == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate)
    
    

    # Training and evaluation loop
    epochs_to_accuracy = None
    for epoch in range(num_epochs2):
        iteration += 1
        train_loss, train_acc = train(model, train_iter, optimizer, criterion)
        # Save the model's state after every iteration
        # checkpoint_path = os.path.join(checkpoint_dir, f'checkpoint_{hyperparameters}_{optimizer_type}_epoch_{epoch + 1}_iteration_{iteration}.pt')
        # save_checkpoint(model, optimizer, iteration, checkpoint_path)
        
        val_loss, val_acc = evaluate(model, val_iter, criterion)

        print(f'Hyperparameters: {hyperparameters}')
        print(f'Optimizer: {optimizer_type}, Epoch {epoch + 1}/{num_epochs2}, '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        if val_acc >= desired_accuracy:
            print(f'Reached the desired accuracy of {desired_accuracy * 100}% on the validation set at epoch {epoch + 1}.')
            epochs_to_accuracy = epoch + 1
            if val_acc > best_val_accuracy:
                best_val_accuracy = val_acc
                best_hyperparameters = hyperparameters
                best_epochs_to_accuracy = epochs_to_accuracy
            break
        

# After the loop, you can evaluate on the test set using the best hyperparameters
if best_hyperparameters:
    print(f'Best hyperparameters: {best_hyperparameters}')
    print(f'Best validation accuracy: {best_val_accuracy:.4f}')

    # Create a model with the best hyperparameters
    best_model = RNNClassifier(vocab_size, best_hyperparameters['embedding_dim2'], best_hyperparameters['hidden_dim2'], label_size, padding_idx, num_layers=best_hyperparameters['num_layers']).to(device)

    # Choose the optimizer based on the best hyperparameters
    if best_hyperparameters['optimizer'] == 'SGD':
        best_optimizer = optim.SGD(best_model.parameters(), lr=best_hyperparameters['learning_rate'])
    elif best_hyperparameters['optimizer'] == 'Adam':
        best_optimizer = optim.Adam(best_model.parameters(), lr=best_hyperparameters['learning_rate'])

    # Train the best model on the entire training dataset
    for epoch in range(num_epochs2):
        train_loss, train_acc = train(best_model, train_iter, best_optimizer, criterion)

    # Evaluate the best model on the test set
    test_loss, test_acc = evaluate(best_model, test_iter, criterion)
    print(f'Test Loss ({best_hyperparameters["optimizer"]}): {test_loss:.4f}, Test Acc ({best_hyperparameters["optimizer"]}): {test_acc:.4f}')
else:
    print("No hyperparameter combination achieved the desired accuracy.")
if best_val_accuracy == 0.0:
    print("No hyperparameter combination reached the desired accuracy.")
    print(f"Best found hyperparameters: {best_hyperparameters}")
# Out:
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 1/100, Train Loss: 1.1096, Train Acc: 0.2010, Val Loss: 1.1241, Val Acc: 0.2925
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 2/100, Train Loss: 1.1061, Train Acc: 0.3668, Val Loss: 1.1197, Val Acc: 0.3206
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 3/100, Train Loss: 1.1024, Train Acc: 0.3849, Val Loss: 1.1157, Val Acc: 0.3270
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 4/100, Train Loss: 1.0996, Train Acc: 0.3823, Val Loss: 1.1122, Val Acc: 0.3406
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 5/100, Train Loss: 1.0971, Train Acc: 0.3832, Val Loss: 1.1087, Val Acc: 0.3579
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 6/100, Train Loss: 1.0943, Train Acc: 0.3847, Val Loss: 1.1052, Val Acc: 0.3697
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 7/100, Train Loss: 1.0921, Train Acc: 0.3840, Val Loss: 1.1022, Val Acc: 0.3769
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 8/100, Train Loss: 1.0895, Train Acc: 0.3858, Val Loss: 1.0992, Val Acc: 0.3851
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 9/100, Train Loss: 1.0876, Train Acc: 0.3859, Val Loss: 1.0965, Val Acc: 0.3942
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 10/100, Train Loss: 1.0855, Train Acc: 0.3848, Val Loss: 1.0938, Val Acc: 0.4060
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 11/100, Train Loss: 1.0833, Train Acc: 0.3864, Val Loss: 1.0912, Val Acc: 0.4087
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 12/100, Train Loss: 1.0814, Train Acc: 0.3893, Val Loss: 1.0886, Val Acc: 0.4251
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 13/100, Train Loss: 1.0791, Train Acc: 0.3927, Val Loss: 1.0862, Val Acc: 0.4314
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 14/100, Train Loss: 1.0782, Train Acc: 0.3878, Val Loss: 1.0840, Val Acc: 0.4423
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 15/100, Train Loss: 1.0764, Train Acc: 0.3886, Val Loss: 1.0819, Val Acc: 0.4460
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 16/100, Train Loss: 1.0750, Train Acc: 0.3887, Val Loss: 1.0798, Val Acc: 0.4523
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 17/100, Train Loss: 1.0739, Train Acc: 0.4130, Val Loss: 1.0778, Val Acc: 0.4614
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 18/100, Train Loss: 1.0724, Train Acc: 0.4182, Val Loss: 1.0762, Val Acc: 0.4596
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 19/100, Train Loss: 1.0712, Train Acc: 0.4190, Val Loss: 1.0746, Val Acc: 0.4632
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 20/100, Train Loss: 1.0694, Train Acc: 0.4204, Val Loss: 1.0732, Val Acc: 0.4678
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 21/100, Train Loss: 1.0688, Train Acc: 0.4203, Val Loss: 1.0715, Val Acc: 0.4759
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 22/100, Train Loss: 1.0678, Train Acc: 0.4171, Val Loss: 1.0699, Val Acc: 0.4814
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 23/100, Train Loss: 1.0671, Train Acc: 0.4165, Val Loss: 1.0684, Val Acc: 0.4832
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 24/100, Train Loss: 1.0659, Train Acc: 0.4199, Val Loss: 1.0671, Val Acc: 0.4868
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 25/100, Train Loss: 1.0648, Train Acc: 0.4201, Val Loss: 1.0657, Val Acc: 0.4905
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 26/100, Train Loss: 1.0642, Train Acc: 0.4174, Val Loss: 1.0644, Val Acc: 0.4896
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 27/100, Train Loss: 1.0629, Train Acc: 0.4189, Val Loss: 1.0633, Val Acc: 0.4886
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 28/100, Train Loss: 1.0627, Train Acc: 0.4183, Val Loss: 1.0621, Val Acc: 0.4905
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 29/100, Train Loss: 1.0612, Train Acc: 0.4182, Val Loss: 1.0611, Val Acc: 0.4932
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 30/100, Train Loss: 1.0607, Train Acc: 0.4204, Val Loss: 1.0600, Val Acc: 0.4959
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 31/100, Train Loss: 1.0601, Train Acc: 0.4185, Val Loss: 1.0592, Val Acc: 0.4950
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 32/100, Train Loss: 1.0597, Train Acc: 0.4187, Val Loss: 1.0581, Val Acc: 0.4959
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 33/100, Train Loss: 1.0590, Train Acc: 0.4199, Val Loss: 1.0572, Val Acc: 0.4941
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 34/100, Train Loss: 1.0581, Train Acc: 0.4201, Val Loss: 1.0563, Val Acc: 0.4977
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 35/100, Train Loss: 1.0576, Train Acc: 0.4199, Val Loss: 1.0554, Val Acc: 0.5005
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 36/100, Train Loss: 1.0571, Train Acc: 0.4183, Val Loss: 1.0547, Val Acc: 0.5050
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 37/100, Train Loss: 1.0564, Train Acc: 0.4215, Val Loss: 1.0541, Val Acc: 0.5032
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 38/100, Train Loss: 1.0564, Train Acc: 0.4197, Val Loss: 1.0532, Val Acc: 0.5041
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 39/100, Train Loss: 1.0556, Train Acc: 0.4226, Val Loss: 1.0525, Val Acc: 0.5086
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 40/100, Train Loss: 1.0550, Train Acc: 0.4218, Val Loss: 1.0518, Val Acc: 0.5086
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 41/100, Train Loss: 1.0544, Train Acc: 0.4204, Val Loss: 1.0512, Val Acc: 0.5086
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 42/100, Train Loss: 1.0543, Train Acc: 0.4203, Val Loss: 1.0507, Val Acc: 0.5077
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 43/100, Train Loss: 1.0540, Train Acc: 0.4197, Val Loss: 1.0502, Val Acc: 0.5068
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 44/100, Train Loss: 1.0534, Train Acc: 0.4196, Val Loss: 1.0495, Val Acc: 0.5068
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 45/100, Train Loss: 1.0537, Train Acc: 0.4190, Val Loss: 1.0491, Val Acc: 0.5068
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 46/100, Train Loss: 1.0532, Train Acc: 0.4206, Val Loss: 1.0485, Val Acc: 0.5077
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 47/100, Train Loss: 1.0531, Train Acc: 0.4215, Val Loss: 1.0481, Val Acc: 0.5077
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 48/100, Train Loss: 1.0526, Train Acc: 0.4206, Val Loss: 1.0477, Val Acc: 0.5095
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 49/100, Train Loss: 1.0522, Train Acc: 0.4218, Val Loss: 1.0472, Val Acc: 0.5123
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 50/100, Train Loss: 1.0518, Train Acc: 0.4219, Val Loss: 1.0471, Val Acc: 0.5114
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 51/100, Train Loss: 1.0517, Train Acc: 0.4206, Val Loss: 1.0469, Val Acc: 0.5132
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 52/100, Train Loss: 1.0513, Train Acc: 0.4209, Val Loss: 1.0465, Val Acc: 0.5141
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 53/100, Train Loss: 1.0516, Train Acc: 0.4204, Val Loss: 1.0462, Val Acc: 0.5132
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 54/100, Train Loss: 1.0516, Train Acc: 0.4195, Val Loss: 1.0458, Val Acc: 0.5159
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 55/100, Train Loss: 1.0509, Train Acc: 0.4195, Val Loss: 1.0454, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 56/100, Train Loss: 1.0503, Train Acc: 0.4215, Val Loss: 1.0452, Val Acc: 0.5177
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 57/100, Train Loss: 1.0509, Train Acc: 0.4198, Val Loss: 1.0448, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 58/100, Train Loss: 1.0504, Train Acc: 0.4210, Val Loss: 1.0446, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 59/100, Train Loss: 1.0498, Train Acc: 0.4211, Val Loss: 1.0443, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 60/100, Train Loss: 1.0500, Train Acc: 0.4223, Val Loss: 1.0438, Val Acc: 0.5204
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 61/100, Train Loss: 1.0499, Train Acc: 0.4206, Val Loss: 1.0436, Val Acc: 0.5204
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 62/100, Train Loss: 1.0497, Train Acc: 0.4219, Val Loss: 1.0433, Val Acc: 0.5223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 63/100, Train Loss: 1.0498, Train Acc: 0.4209, Val Loss: 1.0430, Val Acc: 0.5204
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 64/100, Train Loss: 1.0497, Train Acc: 0.4198, Val Loss: 1.0428, Val Acc: 0.5213
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 65/100, Train Loss: 1.0499, Train Acc: 0.4191, Val Loss: 1.0425, Val Acc: 0.5232
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 66/100, Train Loss: 1.0488, Train Acc: 0.4202, Val Loss: 1.0424, Val Acc: 0.5250
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 67/100, Train Loss: 1.0493, Train Acc: 0.4191, Val Loss: 1.0420, Val Acc: 0.5241
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 68/100, Train Loss: 1.0488, Train Acc: 0.4219, Val Loss: 1.0419, Val Acc: 0.5232
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 69/100, Train Loss: 1.0483, Train Acc: 0.4229, Val Loss: 1.0414, Val Acc: 0.5250
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 70/100, Train Loss: 1.0487, Train Acc: 0.4209, Val Loss: 1.0412, Val Acc: 0.5259
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 71/100, Train Loss: 1.0486, Train Acc: 0.4203, Val Loss: 1.0409, Val Acc: 0.5259
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 72/100, Train Loss: 1.0487, Train Acc: 0.4195, Val Loss: 1.0408, Val Acc: 0.5268
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 73/100, Train Loss: 1.0486, Train Acc: 0.4215, Val Loss: 1.0406, Val Acc: 0.5259
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 74/100, Train Loss: 1.0488, Train Acc: 0.4204, Val Loss: 1.0405, Val Acc: 0.5259
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 75/100, Train Loss: 1.0484, Train Acc: 0.4203, Val Loss: 1.0403, Val Acc: 0.5241
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 76/100, Train Loss: 1.0483, Train Acc: 0.4218, Val Loss: 1.0401, Val Acc: 0.5241
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 77/100, Train Loss: 1.0477, Train Acc: 0.4218, Val Loss: 1.0397, Val Acc: 0.5241
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 78/100, Train Loss: 1.0489, Train Acc: 0.4201, Val Loss: 1.0396, Val Acc: 0.5232
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 79/100, Train Loss: 1.0479, Train Acc: 0.4213, Val Loss: 1.0395, Val Acc: 0.5223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 80/100, Train Loss: 1.0479, Train Acc: 0.4218, Val Loss: 1.0394, Val Acc: 0.5223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 81/100, Train Loss: 1.0483, Train Acc: 0.4202, Val Loss: 1.0393, Val Acc: 0.5213
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 82/100, Train Loss: 1.0483, Train Acc: 0.4205, Val Loss: 1.0393, Val Acc: 0.5213
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 83/100, Train Loss: 1.0482, Train Acc: 0.4219, Val Loss: 1.0392, Val Acc: 0.5213
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 84/100, Train Loss: 1.0480, Train Acc: 0.4209, Val Loss: 1.0392, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 85/100, Train Loss: 1.0483, Train Acc: 0.4201, Val Loss: 1.0393, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 86/100, Train Loss: 1.0477, Train Acc: 0.4204, Val Loss: 1.0392, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 87/100, Train Loss: 1.0476, Train Acc: 0.4208, Val Loss: 1.0390, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 88/100, Train Loss: 1.0473, Train Acc: 0.4210, Val Loss: 1.0389, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 89/100, Train Loss: 1.0477, Train Acc: 0.4198, Val Loss: 1.0390, Val Acc: 0.5213
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 90/100, Train Loss: 1.0482, Train Acc: 0.4195, Val Loss: 1.0390, Val Acc: 0.5204
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 91/100, Train Loss: 1.0480, Train Acc: 0.4202, Val Loss: 1.0391, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 92/100, Train Loss: 1.0478, Train Acc: 0.4211, Val Loss: 1.0392, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 93/100, Train Loss: 1.0474, Train Acc: 0.4217, Val Loss: 1.0392, Val Acc: 0.5195
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 94/100, Train Loss: 1.0475, Train Acc: 0.4219, Val Loss: 1.0391, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 95/100, Train Loss: 1.0475, Train Acc: 0.4218, Val Loss: 1.0390, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 96/100, Train Loss: 1.0476, Train Acc: 0.4215, Val Loss: 1.0390, Val Acc: 0.5177
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 97/100, Train Loss: 1.0478, Train Acc: 0.4208, Val Loss: 1.0390, Val Acc: 0.5186
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 98/100, Train Loss: 1.0473, Train Acc: 0.4219, Val Loss: 1.0389, Val Acc: 0.5168
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 99/100, Train Loss: 1.0477, Train Acc: 0.4204, Val Loss: 1.0389, Val Acc: 0.5168
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: SGD, Epoch 100/100, Train Loss: 1.0469, Train Acc: 0.4228, Val Loss: 1.0388, Val Acc: 0.5168
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 1/100, Train Loss: 1.0554, Train Acc: 0.4211, Val Loss: 1.0492, Val Acc: 0.4051
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 2/100, Train Loss: 1.0470, Train Acc: 0.4215, Val Loss: 1.0608, Val Acc: 0.4051
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 3/100, Train Loss: 1.0467, Train Acc: 0.4195, Val Loss: 1.0961, Val Acc: 0.3152
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 4/100, Train Loss: 1.0469, Train Acc: 0.4215, Val Loss: 1.0641, Val Acc: 0.3978
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 5/100, Train Loss: 1.0451, Train Acc: 0.4209, Val Loss: 1.0741, Val Acc: 0.3978
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 6/100, Train Loss: 1.0448, Train Acc: 0.4246, Val Loss: 1.0677, Val Acc: 0.4024
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 7/100, Train Loss: 1.0438, Train Acc: 0.4235, Val Loss: 1.0695, Val Acc: 0.4033
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 8/100, Train Loss: 1.0426, Train Acc: 0.4258, Val Loss: 1.0748, Val Acc: 0.4060
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 9/100, Train Loss: 1.0424, Train Acc: 0.4219, Val Loss: 1.1266, Val Acc: 0.2952
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 10/100, Train Loss: 1.0420, Train Acc: 0.4240, Val Loss: 1.1041, Val Acc: 0.3615
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 11/100, Train Loss: 1.0408, Train Acc: 0.4244, Val Loss: 1.0812, Val Acc: 0.4242
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 12/100, Train Loss: 1.0384, Train Acc: 0.4304, Val Loss: 1.0703, Val Acc: 0.4723
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 13/100, Train Loss: 1.0390, Train Acc: 0.4217, Val Loss: 1.0800, Val Acc: 0.4332
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 14/100, Train Loss: 1.0382, Train Acc: 0.4264, Val Loss: 1.0923, Val Acc: 0.4423
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 15/100, Train Loss: 1.0369, Train Acc: 0.4264, Val Loss: 1.1060, Val Acc: 0.4541
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 16/100, Train Loss: 1.0358, Train Acc: 0.4325, Val Loss: 1.1111, Val Acc: 0.4396
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 17/100, Train Loss: 1.0305, Train Acc: 0.4576, Val Loss: 1.1203, Val Acc: 0.4396
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 18/100, Train Loss: 1.0201, Train Acc: 0.4800, Val Loss: 1.1016, Val Acc: 0.4550
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 19/100, Train Loss: 1.0061, Train Acc: 0.5020, Val Loss: 1.0905, Val Acc: 0.4559
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 20/100, Train Loss: 0.9957, Train Acc: 0.5226, Val Loss: 1.0953, Val Acc: 0.4496
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 21/100, Train Loss: 0.9826, Train Acc: 0.5421, Val Loss: 1.1025, Val Acc: 0.4432
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 22/100, Train Loss: 0.9739, Train Acc: 0.5520, Val Loss: 1.1311, Val Acc: 0.4223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 23/100, Train Loss: 0.9595, Train Acc: 0.5710, Val Loss: 1.1405, Val Acc: 0.4060
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 24/100, Train Loss: 0.9558, Train Acc: 0.5728, Val Loss: 1.1190, Val Acc: 0.4205
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 25/100, Train Loss: 0.9450, Train Acc: 0.5870, Val Loss: 1.1372, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 26/100, Train Loss: 0.9379, Train Acc: 0.5929, Val Loss: 1.1446, Val Acc: 0.4114
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 27/100, Train Loss: 0.9319, Train Acc: 0.5955, Val Loss: 1.1346, Val Acc: 0.4369
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 28/100, Train Loss: 0.9247, Train Acc: 0.6040, Val Loss: 1.1361, Val Acc: 0.4323
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 29/100, Train Loss: 0.9214, Train Acc: 0.6066, Val Loss: 1.1575, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 30/100, Train Loss: 0.9194, Train Acc: 0.6100, Val Loss: 1.1641, Val Acc: 0.4251
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 31/100, Train Loss: 0.9074, Train Acc: 0.6170, Val Loss: 1.1423, Val Acc: 0.4369
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 32/100, Train Loss: 0.9017, Train Acc: 0.6234, Val Loss: 1.1629, Val Acc: 0.4323
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 33/100, Train Loss: 0.8959, Train Acc: 0.6261, Val Loss: 1.1524, Val Acc: 0.4351
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 34/100, Train Loss: 0.8999, Train Acc: 0.6248, Val Loss: 1.1721, Val Acc: 0.4305
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 35/100, Train Loss: 0.9029, Train Acc: 0.6268, Val Loss: 1.1611, Val Acc: 0.4151
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 36/100, Train Loss: 0.8974, Train Acc: 0.6297, Val Loss: 1.1417, Val Acc: 0.4369
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 37/100, Train Loss: 0.8861, Train Acc: 0.6351, Val Loss: 1.1618, Val Acc: 0.4369
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 38/100, Train Loss: 0.8822, Train Acc: 0.6396, Val Loss: 1.1710, Val Acc: 0.4332
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 39/100, Train Loss: 0.8801, Train Acc: 0.6413, Val Loss: 1.1619, Val Acc: 0.4369
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 40/100, Train Loss: 0.8750, Train Acc: 0.6443, Val Loss: 1.1699, Val Acc: 0.4378
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 41/100, Train Loss: 0.8728, Train Acc: 0.6458, Val Loss: 1.1835, Val Acc: 0.4487
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 42/100, Train Loss: 0.8615, Train Acc: 0.6529, Val Loss: 1.1615, Val Acc: 0.4623
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 43/100, Train Loss: 0.8633, Train Acc: 0.6546, Val Loss: 1.1815, Val Acc: 0.4396
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 44/100, Train Loss: 0.8595, Train Acc: 0.6568, Val Loss: 1.1707, Val Acc: 0.4469
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 45/100, Train Loss: 0.8534, Train Acc: 0.6599, Val Loss: 1.1689, Val Acc: 0.4469
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 46/100, Train Loss: 0.8533, Train Acc: 0.6598, Val Loss: 1.1654, Val Acc: 0.4487
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 47/100, Train Loss: 0.8455, Train Acc: 0.6674, Val Loss: 1.1956, Val Acc: 0.4305
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 48/100, Train Loss: 0.8411, Train Acc: 0.6684, Val Loss: 1.2001, Val Acc: 0.4441
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 49/100, Train Loss: 0.8258, Train Acc: 0.6771, Val Loss: 1.1794, Val Acc: 0.4505
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 50/100, Train Loss: 0.8241, Train Acc: 0.6759, Val Loss: 1.1896, Val Acc: 0.4460
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 51/100, Train Loss: 0.8199, Train Acc: 0.6802, Val Loss: 1.1814, Val Acc: 0.4514
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 52/100, Train Loss: 0.8148, Train Acc: 0.6840, Val Loss: 1.1960, Val Acc: 0.4460
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 53/100, Train Loss: 0.8044, Train Acc: 0.6897, Val Loss: 1.2170, Val Acc: 0.4578
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 54/100, Train Loss: 0.7994, Train Acc: 0.6931, Val Loss: 1.2075, Val Acc: 0.4559
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 55/100, Train Loss: 0.7925, Train Acc: 0.6993, Val Loss: 1.2134, Val Acc: 0.4605
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 56/100, Train Loss: 0.7899, Train Acc: 0.7021, Val Loss: 1.2138, Val Acc: 0.4632
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 57/100, Train Loss: 0.7787, Train Acc: 0.7062, Val Loss: 1.2503, Val Acc: 0.4487
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 58/100, Train Loss: 0.7699, Train Acc: 0.7110, Val Loss: 1.2593, Val Acc: 0.4514
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 59/100, Train Loss: 0.7666, Train Acc: 0.7152, Val Loss: 1.2408, Val Acc: 0.4532
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 60/100, Train Loss: 0.7557, Train Acc: 0.7221, Val Loss: 1.2655, Val Acc: 0.4596
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 61/100, Train Loss: 0.7487, Train Acc: 0.7250, Val Loss: 1.2624, Val Acc: 0.4505
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 62/100, Train Loss: 0.7457, Train Acc: 0.7275, Val Loss: 1.2868, Val Acc: 0.4532
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 63/100, Train Loss: 0.7407, Train Acc: 0.7281, Val Loss: 1.2927, Val Acc: 0.4559
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 64/100, Train Loss: 0.7289, Train Acc: 0.7363, Val Loss: 1.2826, Val Acc: 0.4705
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 65/100, Train Loss: 0.7173, Train Acc: 0.7410, Val Loss: 1.2960, Val Acc: 0.4723
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 66/100, Train Loss: 0.7198, Train Acc: 0.7416, Val Loss: 1.2855, Val Acc: 0.4877
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 67/100, Train Loss: 0.7119, Train Acc: 0.7445, Val Loss: 1.3212, Val Acc: 0.4759
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 68/100, Train Loss: 0.7041, Train Acc: 0.7504, Val Loss: 1.3156, Val Acc: 0.4805
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 69/100, Train Loss: 0.6996, Train Acc: 0.7507, Val Loss: 1.3378, Val Acc: 0.4750
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 70/100, Train Loss: 0.6953, Train Acc: 0.7508, Val Loss: 1.3479, Val Acc: 0.4696
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 71/100, Train Loss: 0.6989, Train Acc: 0.7506, Val Loss: 1.3487, Val Acc: 0.4668
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 72/100, Train Loss: 0.6804, Train Acc: 0.7583, Val Loss: 1.3495, Val Acc: 0.4768
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 73/100, Train Loss: 0.6832, Train Acc: 0.7547, Val Loss: 1.3615, Val Acc: 0.4841
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 74/100, Train Loss: 0.6806, Train Acc: 0.7577, Val Loss: 1.3807, Val Acc: 0.4705
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 75/100, Train Loss: 0.6745, Train Acc: 0.7597, Val Loss: 1.4003, Val Acc: 0.4705
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 76/100, Train Loss: 0.6574, Train Acc: 0.7653, Val Loss: 1.3887, Val Acc: 0.4623
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 77/100, Train Loss: 0.6613, Train Acc: 0.7662, Val Loss: 1.4036, Val Acc: 0.4805
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 78/100, Train Loss: 0.6580, Train Acc: 0.7670, Val Loss: 1.3908, Val Acc: 0.4777
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 79/100, Train Loss: 0.6532, Train Acc: 0.7691, Val Loss: 1.4047, Val Acc: 0.4741
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 80/100, Train Loss: 0.6454, Train Acc: 0.7671, Val Loss: 1.4342, Val Acc: 0.4723
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 81/100, Train Loss: 0.6373, Train Acc: 0.7731, Val Loss: 1.4214, Val Acc: 0.4777
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 82/100, Train Loss: 0.6344, Train Acc: 0.7752, Val Loss: 1.4229, Val Acc: 0.4659
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 83/100, Train Loss: 0.6264, Train Acc: 0.7766, Val Loss: 1.4412, Val Acc: 0.4741
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 84/100, Train Loss: 0.6254, Train Acc: 0.7766, Val Loss: 1.4311, Val Acc: 0.4768
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 85/100, Train Loss: 0.6118, Train Acc: 0.7807, Val Loss: 1.4326, Val Acc: 0.4787
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 86/100, Train Loss: 0.6073, Train Acc: 0.7815, Val Loss: 1.4233, Val Acc: 0.4796
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 87/100, Train Loss: 0.6013, Train Acc: 0.7828, Val Loss: 1.4603, Val Acc: 0.4759
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 88/100, Train Loss: 0.5910, Train Acc: 0.7852, Val Loss: 1.4765, Val Acc: 0.4714
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 89/100, Train Loss: 0.5931, Train Acc: 0.7842, Val Loss: 1.4581, Val Acc: 0.4705
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 90/100, Train Loss: 0.5845, Train Acc: 0.7851, Val Loss: 1.4628, Val Acc: 0.4650
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 91/100, Train Loss: 0.5765, Train Acc: 0.7882, Val Loss: 1.4425, Val Acc: 0.4759
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 92/100, Train Loss: 0.5623, Train Acc: 0.7920, Val Loss: 1.4752, Val Acc: 0.4650
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 93/100, Train Loss: 0.5581, Train Acc: 0.7914, Val Loss: 1.4514, Val Acc: 0.4768
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 94/100, Train Loss: 0.5587, Train Acc: 0.7938, Val Loss: 1.4321, Val Acc: 0.4841
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 95/100, Train Loss: 0.5443, Train Acc: 0.7968, Val Loss: 1.4533, Val Acc: 0.4814
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# Optimizer: Adam, Epoch 96/100, Train Loss: 0.5404, Train Acc: 0.7966, Val Loss: 1.4777, Val Acc: 0.4796
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'momentum': 0.8}
# ...
# Optimizer: SGD, Epoch 74/100, Train Loss: 1.0466, Train Acc: 0.4231, Val Loss: 1.0425, Val Acc: 0.4523
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 75/100, Train Loss: 1.0462, Train Acc: 0.4221, Val Loss: 1.0431, Val Acc: 0.4469
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 76/100, Train Loss: 1.0465, Train Acc: 0.4213, Val Loss: 1.0435, Val Acc: 0.4405
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 77/100, Train Loss: 1.0464, Train Acc: 0.4232, Val Loss: 1.0441, Val Acc: 0.4378
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 78/100, Train Loss: 1.0464, Train Acc: 0.4219, Val Loss: 1.0452, Val Acc: 0.4260
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 79/100, Train Loss: 1.0461, Train Acc: 0.4229, Val Loss: 1.0452, Val Acc: 0.4296
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 80/100, Train Loss: 1.0459, Train Acc: 0.4225, Val Loss: 1.0455, Val Acc: 0.4323
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 81/100, Train Loss: 1.0460, Train Acc: 0.4233, Val Loss: 1.0448, Val Acc: 0.4314
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 82/100, Train Loss: 1.0465, Train Acc: 0.4228, Val Loss: 1.0475, Val Acc: 0.4223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 83/100, Train Loss: 1.0461, Train Acc: 0.4216, Val Loss: 1.0478, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 84/100, Train Loss: 1.0464, Train Acc: 0.4233, Val Loss: 1.0474, Val Acc: 0.4242
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 85/100, Train Loss: 1.0462, Train Acc: 0.4226, Val Loss: 1.0482, Val Acc: 0.4223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 86/100, Train Loss: 1.0464, Train Acc: 0.4226, Val Loss: 1.0495, Val Acc: 0.4133
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 87/100, Train Loss: 1.0462, Train Acc: 0.4224, Val Loss: 1.0489, Val Acc: 0.4151
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 88/100, Train Loss: 1.0460, Train Acc: 0.4223, Val Loss: 1.0468, Val Acc: 0.4223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 89/100, Train Loss: 1.0457, Train Acc: 0.4233, Val Loss: 1.0457, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 90/100, Train Loss: 1.0461, Train Acc: 0.4225, Val Loss: 1.0458, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 91/100, Train Loss: 1.0463, Train Acc: 0.4225, Val Loss: 1.0462, Val Acc: 0.4223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 92/100, Train Loss: 1.0462, Train Acc: 0.4232, Val Loss: 1.0464, Val Acc: 0.4242
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 93/100, Train Loss: 1.0461, Train Acc: 0.4225, Val Loss: 1.0462, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 94/100, Train Loss: 1.0460, Train Acc: 0.4242, Val Loss: 1.0442, Val Acc: 0.4287
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 95/100, Train Loss: 1.0458, Train Acc: 0.4225, Val Loss: 1.0454, Val Acc: 0.4251
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 96/100, Train Loss: 1.0462, Train Acc: 0.4232, Val Loss: 1.0463, Val Acc: 0.4269
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 97/100, Train Loss: 1.0458, Train Acc: 0.4236, Val Loss: 1.0468, Val Acc: 0.4260
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 98/100, Train Loss: 1.0464, Train Acc: 0.4231, Val Loss: 1.0476, Val Acc: 0.4214
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 99/100, Train Loss: 1.0459, Train Acc: 0.4228, Val Loss: 1.0486, Val Acc: 0.4205
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'SGD', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: SGD, Epoch 100/100, Train Loss: 1.0459, Train Acc: 0.4224, Val Loss: 1.0479, Val Acc: 0.4233
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 1/100, Train Loss: 1.0515, Train Acc: 0.4133, Val Loss: 1.1461, Val Acc: 0.3660
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 2/100, Train Loss: 1.0489, Train Acc: 0.4161, Val Loss: 1.2000, Val Acc: 0.4005
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 3/100, Train Loss: 1.0451, Train Acc: 0.4180, Val Loss: 1.1492, Val Acc: 0.3470
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 4/100, Train Loss: 1.0445, Train Acc: 0.4175, Val Loss: 1.1851, Val Acc: 0.3915
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 5/100, Train Loss: 1.0410, Train Acc: 0.4212, Val Loss: 1.1829, Val Acc: 0.3688
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 6/100, Train Loss: 1.0433, Train Acc: 0.4250, Val Loss: 1.1483, Val Acc: 0.3733
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 7/100, Train Loss: 1.0388, Train Acc: 0.4245, Val Loss: 1.1950, Val Acc: 0.3697
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 8/100, Train Loss: 1.0366, Train Acc: 0.4265, Val Loss: 1.2297, Val Acc: 0.3751
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 9/100, Train Loss: 1.0372, Train Acc: 0.4265, Val Loss: 1.3109, Val Acc: 0.3070
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 10/100, Train Loss: 1.0636, Train Acc: 0.4171, Val Loss: 1.1184, Val Acc: 0.3697
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 11/100, Train Loss: 1.0580, Train Acc: 0.4136, Val Loss: 1.1341, Val Acc: 0.3488
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 12/100, Train Loss: 1.0542, Train Acc: 0.4146, Val Loss: 1.1281, Val Acc: 0.3978
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 13/100, Train Loss: 1.0542, Train Acc: 0.4114, Val Loss: 1.1052, Val Acc: 0.3651
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 14/100, Train Loss: 1.0542, Train Acc: 0.4165, Val Loss: 1.1415, Val Acc: 0.3351
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 15/100, Train Loss: 1.0495, Train Acc: 0.4243, Val Loss: 1.1357, Val Acc: 0.3942
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 16/100, Train Loss: 1.0501, Train Acc: 0.4203, Val Loss: 1.1293, Val Acc: 0.3851
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 17/100, Train Loss: 1.0468, Train Acc: 0.4170, Val Loss: 1.1121, Val Acc: 0.3742
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 18/100, Train Loss: 1.0424, Train Acc: 0.4268, Val Loss: 1.1257, Val Acc: 0.3887
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 19/100, Train Loss: 1.0420, Train Acc: 0.4285, Val Loss: 1.1178, Val Acc: 0.4160
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 20/100, Train Loss: 1.0346, Train Acc: 0.4425, Val Loss: 1.1673, Val Acc: 0.4242
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 21/100, Train Loss: 1.0189, Train Acc: 0.4950, Val Loss: 1.1375, Val Acc: 0.4387
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 22/100, Train Loss: 0.9961, Train Acc: 0.5350, Val Loss: 1.1345, Val Acc: 0.4469
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 23/100, Train Loss: 0.9966, Train Acc: 0.5312, Val Loss: 1.1154, Val Acc: 0.4323
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 24/100, Train Loss: 0.9815, Train Acc: 0.5541, Val Loss: 1.1457, Val Acc: 0.4559
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 25/100, Train Loss: 0.9751, Train Acc: 0.5604, Val Loss: 1.1086, Val Acc: 0.4941
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 26/100, Train Loss: 0.9584, Train Acc: 0.5747, Val Loss: 1.1582, Val Acc: 0.4714
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 27/100, Train Loss: 0.9486, Train Acc: 0.5866, Val Loss: 1.1590, Val Acc: 0.4886
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 28/100, Train Loss: 0.9262, Train Acc: 0.6056, Val Loss: 1.1418, Val Acc: 0.4950
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 29/100, Train Loss: 0.9223, Train Acc: 0.6115, Val Loss: 1.0988, Val Acc: 0.5095
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 30/100, Train Loss: 0.9270, Train Acc: 0.6057, Val Loss: 1.1160, Val Acc: 0.5223
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 31/100, Train Loss: 0.9107, Train Acc: 0.6227, Val Loss: 1.0823, Val Acc: 0.5304
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 32/100, Train Loss: 0.9270, Train Acc: 0.6097, Val Loss: 1.1165, Val Acc: 0.4859
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 33/100, Train Loss: 0.9164, Train Acc: 0.6163, Val Loss: 1.1113, Val Acc: 0.4923
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 34/100, Train Loss: 0.9137, Train Acc: 0.6134, Val Loss: 1.1663, Val Acc: 0.5095
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 35/100, Train Loss: 0.9237, Train Acc: 0.6046, Val Loss: 1.0952, Val Acc: 0.5104
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 36/100, Train Loss: 0.9360, Train Acc: 0.5865, Val Loss: 1.1602, Val Acc: 0.4659
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 37/100, Train Loss: 0.9438, Train Acc: 0.5973, Val Loss: 1.1031, Val Acc: 0.5005
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 38/100, Train Loss: 0.9488, Train Acc: 0.5866, Val Loss: 1.0993, Val Acc: 0.4923
# Hyperparameters: {'embedding_dim2': 128, 'hidden_dim2': 128, 'num_layers': 1, 'optimizer': 'Adam', 'learning_rate': 0.001, 'momentum': None}
# Optimizer: Adam, Epoch 39/100, Train Loss: 0.9382, Train Acc: 0.5996, Val Loss: 1.0811, Val Acc: 0.5204

# %%
print(best_hyperparameters)

# %%
class LSTMWithBatchNorm(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, label_size, num_layers, dropout, padding_idx):
        super(LSTMWithBatchNorm, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.label_size = label_size
        self.num_layers = num_layers

        # Define the layers required for sentiment analysis.
        self.embedding = nn.Embedding(self.vocab_size, self.embedding_dim, padding_idx=padding_idx)
        self.lstm = nn.LSTM(self.embedding_dim, self.hidden_dim, num_layers=self.num_layers, batch_first=True, dropout=dropout)
        self.layernorm = nn.LayerNorm(self.hidden_dim)  # Add BatchNorm layer
        self.fc = nn.Linear(self.hidden_dim, self.label_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        # Implement the forward function of the model.
        embedded = self.embedding(text)
        lstm_output, _ = self.lstm(embedded)
        # Apply BatchNorm
        normalized_output = self.layernorm(lstm_output)
        output = self.fc(normalized_output[:, -1, :])
        return output

# %%
import matplotlib.pyplot as plt

# Train and evaluate your model
num_epochs = 20
learning_rate = 0.001

vocab_size = len(TEXT.vocab)
label_size = len(LABEL.vocab)
EMBEDDING_DIM = 512
HIDDEN_DIM = 512
NUM_LAYERS = 2  # Make sure this is an integer
DROPOUT = 0.5  # Specify as a float value
PADDING_IDX = TEXT.vocab.stoi['<pad>']

optimizer = optim.Adam(model.parameters(),lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)
criterion = nn.CrossEntropyLoss()

# Create the model instance
model = LSTMWithBatchNorm(vocab_size, EMBEDDING_DIM, HIDDEN_DIM, label_size, NUM_LAYERS, DROPOUT, PADDING_IDX).to(device)

# Training
CLIP = 1.0  # Gradient clipping threshold

# Lists to store training and validation loss
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    train_loss, train_acc = train(model, train_iter, optimizer, criterion)
    val_loss, val_acc = evaluate(model, val_iter, criterion)
    
    # Append the loss values to the lists
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    scheduler.step()
    
    print(f'Epoch: {epoch+1:02}')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\tVal Loss: {val_loss:.3f} | Val Acc: {val_acc*100:.2f}%')

# Plot the loss curve
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Over Time')
plt.show()

# Evaluation
model.eval()
test_loss, test_acc = evaluate(model, test_iter, criterion)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')

# %%
import torch.nn as nn

class GRUWithLayerNorm(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, label_size, num_layers, dropout, padding_idx):
        super(GRUWithLayerNorm, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.label_size = label_size
        self.num_layers = num_layers

        # Define the layers required for sentiment analysis.
        self.embedding = nn.Embedding(self.vocab_size, self.embedding_dim, padding_idx=padding_idx)
        self.gru = nn.GRU(self.embedding_dim, self.hidden_dim, num_layers=self.num_layers, batch_first=True, dropout=dropout)
        self.layernorm = nn.LayerNorm(self.hidden_dim)  # Add LayerNorm layer
        self.fc = nn.Linear(self.hidden_dim, self.label_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):
        # Implement the forward function of the model.
        embedded = self.embedding(text)
        gru_output, _ = self.gru(embedded)
        # Apply LayerNorm
        normalized_output = self.layernorm(gru_output)
        output = self.fc(normalized_output[:, -1, :])
        return output

# %%
# Train and evaluate your model
num_epochs = 20
learning_rate = 0.0001

vocab_size = len(TEXT.vocab)
label_size = len(LABEL.vocab)
EMBEDDING_DIM = 1024
HIDDEN_DIM = 1024
NUM_LAYERS = 4  # Make sure this is an integer
DROPOUT = 0.3  # Specify as a float value
PADDING_IDX = TEXT.vocab.stoi['<pad>']
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# Create the model instance
model = GRUWithLayerNorm(vocab_size, EMBEDDING_DIM, HIDDEN_DIM, label_size, NUM_LAYERS, DROPOUT, PADDING_IDX).to(device)

# Training
CLIP = 1.0  # Gradient clipping threshold

# Lists to store training and validation loss
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    train_loss, train_acc = train(model, train_iter, optimizer, criterion)
    val_loss, val_acc = evaluate(model, val_iter, criterion)
    
    # Append the loss values to the lists
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    print(f'Epoch: {epoch+1:02}')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\tVal Loss: {val_loss:.3f} | Val Acc: {val_acc*100:.2f}%')

# Plot the loss curve
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Over Time')
plt.show()

# Evaluation
model.eval()
test_loss, test_acc = evaluate(model, test_iter, criterion)
print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Epoch: 01
# 	Train Loss: 1.126 | Train Acc: 39.09%
# 	Val Loss: 1.131 | Val Acc: 36.97%
# Epoch: 02
# 	Train Loss: 1.127 | Train Acc: 38.75%
# 	Val Loss: 1.131 | Val Acc: 36.97%
# Epoch: 03
# 	Train Loss: 1.127 | Train Acc: 38.85%
# 	Val Loss: 1.131 | Val Acc: 36.97%
# Epoch: 04
# 	Train Loss: 1.127 | Train Acc: 38.89%
# 	Val Loss: 1.131 | Val Acc: 36.97%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13372\1027892177.py in <module>
#      25 for epoch in range(num_epochs):
#      26     model.train()
# ---> 27     train_loss, train_acc = train(model, train_iter, optimizer, criterion)
#      28     val_loss, val_acc = evaluate(model, val_iter, criterion)
#      29
#
# ~\AppData\Local\Temp\ipykernel_13372\2474193124.py in train(model, iterator, optimizer, criterion, clip_grad)
#      11         predictions = model(text)
#      12         loss = criterion(predictions, label)
# ---> 13         loss.backward()
#      14
#      15         # Gradient clipping to prevent exploding gradients
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
